# %% [markdown]
# <img src="http://openenergy-platform.org/static/OEP_logo_2_no_text.svg" alt="OpenEnergy Platform" height="100" width="100"  align="left"/>
#
# # Open Energy Platform
# <br><br>
#
# ## Download MaStR and Aggregate on Subregions
# Repository: https://github.com/openego/oedialect
#
# Please report bugs and improvements here: https://github.com/OpenEnergyPlatform/oedialect/issues <br>
# Using SAIO functions to setup SqlAlchemy classes: https://github.com/coroa/saio

# %%
__copyright__ = "Reiner Lemoine Institut"
__license__   = "GNU Affero General Public License Version 3 (AGPL-3.0)"
__url__       = "https://github.com/openego/data_processing/blob/master/LICENSE"
__author__    = "Ludee"

# %%
import oedialect
import saio
import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker

import pandas as pd
import numpy as np
import getpass

import matplotlib.pyplot as plt
from matplotlib import collections
import geopandas as gpd
from geopandas.tools import sjoin

# %matplotlib inline

# %% [markdown]
# ## Connection to OEP

# %% [markdown]
# We first need to connect to the OEP, using our user name and token. <br>
# Note: You ca view your token on your OEP profile page after logging in.

# %%
# White spaces in the username are fine!
user = input('Enter OEP-username:')
token = getpass.getpass('Token:')
# Out:
# Enter OEP-username:Ludee
# Token:········

# %% [markdown]
# Create an SQLAlchemy engine. <br>
# The engine is what 'speaks' oedialect to the database API. We need to tell it where the database is and pass our credentials.

# %%
# Create Engine:
oep_url = 'openenergy-platform.org' #'193.175.187.164' #'oep.iks.cs.ovgu.de'
oed = f'postgresql+oedialect://{user}:{token}@{oep_url}'

engine = sa.create_engine(oed)
metadata = sa.MetaData(bind=engine)
print(metadata)
# Out:
# MetaData(bind=Engine(postgresql+oedialect://Ludee:***@openenergy-platform.org))

# %% [markdown]
# ## Setup ORM

# %% [markdown]
# Retrieve the [Object-relational mapping (ORM)](https://en.wikipedia.org/wiki/Object-relational_mapping) from the OEP.

# %%
saio.register_schema("boundaries", engine)
saio.register_schema("model_draft", engine)

# %% [markdown]
# ## Download data from OEP

# %% [markdown]
# ### Bundesländer & Kreise & Gemeinden

# %%
from saio.boundaries import bkg_vg250_2_lan as BkgVg250Lan
from saio.boundaries import bkg_vg250_4_krs as BkgVg250Krs
from saio.boundaries import bkg_vg250_6_gem as BkgVg250Gem

# %%
Session = sessionmaker(bind=engine)
session = Session()
try:
    df_lan = saio.as_pandas(session.query(BkgVg250Lan))
    df_krs = saio.as_pandas(session.query(BkgVg250Krs))
    df_gem = saio.as_pandas(session.query(BkgVg250Gem))
    session.commit()
    print('Querry successful!')
except Exception as e:
    session.rollback()
    raise
    print('Querry incomplete!')
finally:
    session.close()
# Out:
# Querry successful!

# %%
ax = df_lan.plot(figsize=(5, 5), color='white', edgecolor='black')

# %%
ax = df_lan.plot(figsize=(10, 10), color='white', edgecolor='black', linewidth=2)
df_krs.plot(ax=ax, alpha=0.5, color='white', edgecolor='tab:blue', linewidth=1)
df_gem.plot(ax=ax, alpha=0.1, color='white', edgecolor='tab:red')

# %%
df_lan
# Out:
#    reference_date  id  ade   gf  bsg  rs ags        sdv_rs  \
# 0      2016-01-01   1  2.0  4.0  1.0  10  10  100410100100
# 1      2016-01-01   2  2.0  4.0  1.0  08  08  081110000000
# 2      2016-01-01   3  2.0  4.0  1.0  05  05  051110000000
# 3      2016-01-01   5  2.0  4.0  1.0  04  04  040110000000
# 4      2016-01-01   6  2.0  4.0  1.0  06  06  064140000000
# 5      2016-01-01   7  2.0  4.0  1.0  12  12  120540000000
# 6      2016-01-01   8  2.0  4.0  1.0  03  03  032410001001
# 7      2016-01-01   9  2.0  4.0  1.0  13  13  130040000000
# 8      2016-01-01  10  2.0  4.0  1.0  07  07  073150000000
# 9      2016-01-01  11  2.0  4.0  1.0  11  11  110000000000
# 10     2016-01-01  12  2.0  1.0  9.0  08  08  081110000000
# 11     2016-01-01  13  2.0  2.0  1.0  04  04  040110000000
# 12     2016-01-01  21  2.0  4.0  1.0  14  14  146120000000
# 13     2016-01-01  22  2.0  4.0  1.0  15  15  150030000000
# 14     2016-01-01  23  2.0  4.0  1.0  02  02  020000000000
# 15     2016-01-01  14  2.0  1.0  9.0  09  09  091620000000
# 16     2016-01-01  15  2.0  1.0  1.0  08  08  081110000000
# 17     2016-01-01  16  2.0  2.0  1.0  08  08  081110000000
# 18     2016-01-01  31  2.0  4.0  1.0  16  16  160510000000
# 19     2016-01-01  33  2.0  4.0  1.0  09  09  091620000000
# 20     2016-01-01  34  2.0  1.0  1.0  03  03  032410001001
# 21     2016-01-01  17  2.0  2.0  1.0  02  02  020000000000
# 22     2016-01-01  19  2.0  3.0  1.0  01  01  010020000000
# 23     2016-01-01  25  2.0  2.0  1.0  03  03  032410001001
# 24     2016-01-01  26  2.0  4.0  1.0  01  01  010020000000
# 25     2016-01-01  27  2.0  2.0  1.0  01  01  010020000000
# 26     2016-01-01  29  2.0  3.0  1.0  13  13  130040000000
# 27     2016-01-01  30  2.0  2.0  1.0  13  13  130040000000
#
#                              gen                   bez  ...  sn_v1 sn_v2 sn_g  \
# 0                       Saarland                  Land  ...     00    00  000
# 1              Baden-Württemberg                  Land  ...     00    00  000
# 2            Nordrhein-Westfalen                  Land  ...     00    00  000
# 3                         Bremen      Freie Hansestadt  ...     00    00  000
# 4                         Hessen                  Land  ...     00    00  000
# 5                    Brandenburg                  Land  ...     00    00  000
# 6                  Niedersachsen                  Land  ...     00    00  000
# 7         Mecklenburg-Vorpommern                  Land  ...     00    00  000
# 8                Rheinland-Pfalz                  Land  ...     00    00  000
# 9                         Berlin                  Land  ...     00    00  000
# 10  Baden-Württemberg (Bodensee)                  Land  ...     00    00  000
# 11                        Bremen      Freie Hansestadt  ...     00    00  000
# 12                       Sachsen             Freistaat  ...     00    00  000
# 13                Sachsen-Anhalt                  Land  ...     00    00  000
# 14                       Hamburg  Freie und Hansestadt  ...     00    00  000
# 15             Bayern (Bodensee)             Freistaat  ...     00    00  000
# 16             Baden-Württemberg                  Land  ...     00    00  000
# 17             Baden-Württemberg                  Land  ...     00    00  000
# 18                     Thüringen             Freistaat  ...     00    00  000
# 19                        Bayern             Freistaat  ...     00    00  000
# 20                 Niedersachsen                  Land  ...     00    00  000
# 21                       Hamburg  Freie und Hansestadt  ...     00    00  000
# 22            Schleswig-Holstein                  Land  ...     00    00  000
# 23                 Niedersachsen                  Land  ...     00    00  000
# 24            Schleswig-Holstein                  Land  ...     00    00  000
# 25            Schleswig-Holstein                  Land  ...     00    00  000
# 26        Mecklenburg-Vorpommern                  Land  ...     00    00  000
# 27        Mecklenburg-Vorpommern                  Land  ...     00    00  000
#
#    fk_s3 nuts          rs_0     ags_0         wsk          debkg_id  \
# 0      0  DEC  100000000000  10000000  2009-01-01  DEBKGDL20000E5E3
# 1      0  DE1  080000000000  08000000  1997-01-01  DEBKGDL20000E603
# 2      0  DEA  050000000000  05000000  2009-11-01  DEBKGDL20000E6GR
# 3      0  DE5  040000000000  04000000  2010-01-01  DEBKGDL20000E0SF
# 4      0  DE7  060000000000  06000000  2015-01-01  DEBKGDL20000E3LK
# 5      0  DE4  120000000000  12000000  1999-01-20  DEBKGDL20000E675
# 6      0  DE9  030000000000  03000000  2015-01-01  DEBKGDL20000E6EW
# 7      0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 8      0  DEB  070000000000  07000000  2004-01-01  DEBKGDL20000E6ZO
# 9      0  DE3  110000000000  11000000  1990-10-03  DEBKGDL20000E0P5
# 10     0  DE1  080000000000  08000000  1997-01-01  DEBKGDL20000QBLE
# 11     0  DE5  040000000000  04000000  2010-01-01  DEBKGDL20000004N
# 12     0  DED  140000000000  14000000  2014-02-01  DEBKGDL20000E3VH
# 13     0  DEE  150000000000  15000000  2014-02-01  DEBKGDL20000E66C
# 14     0  DE6  020000000000  02000000  1974-01-01  DEBKGDL20000E6GD
# 15     0  DE2  090000000000  09000000  2011-07-01  DEBKGDL20000QBLF
# 16     0  DE1  080000000000  08000000  1997-01-01  DEBKGDL20000HKPK
# 17     0  DE1  080000000000  08000000  1997-01-01  DEBKGDL20000JP1Z
# 18     0  DEG  160000000000  16000000  2014-02-01  DEBKGDL20000E09Y
# 19     0  DE2  090000000000  09000000  2011-07-01  DEBKGDL20000E5HO
# 20     0  DE9  030000000000  03000000  2015-01-01  DEBKGDL200010SHR
# 21     0  DE6  020000000000  02000000  1974-01-01  DEBKGDL20000QMRX
# 22     0  DEF  010000000000  01000000  2012-02-01  DEBKGDL20000QBMI
# 23     0  DE9  030000000000  03000000  2015-01-01  DEBKGDL200000041
# 24     0  DEF  010000000000  01000000  2012-02-01  DEBKGDL200000029
# 25     0  DEF  010000000000  01000000  2012-02-01  DEBKGDL20000E68Q
# 26     0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000QBMH
# 27     0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000E5I7
#
#                                                  geom
# 0   MULTIPOLYGON (((3359860.552 5501116.386, 33601...
# 1   MULTIPOLYGON (((3546990.992 5516203.221, 35469...
# 2   MULTIPOLYGON (((3477670.596 5820656.545, 34777...
# 3   MULTIPOLYGON (((3466988.203 5899769.937, 34670...
# 4   MULTIPOLYGON (((3534329.215 5723671.601, 35343...
# 5   MULTIPOLYGON (((3818085.729 5947040.866, 38181...
# 6   MULTIPOLYGON (((3479512.889 5973250.388, 34794...
# 7   MULTIPOLYGON (((3728408.028 6045375.810, 37284...
# 8   MULTIPOLYGON (((3416345.666 5645512.890, 34165...
# 9   MULTIPOLYGON (((3802758.415 5846732.996, 38027...
# 10  MULTIPOLYGON (((3503439.260 5297581.159, 35034...
# 11  MULTIPOLYGON (((3468325.115 5941751.882, 34683...
# 12  MULTIPOLYGON (((3766020.421 5734703.377, 37662...
# 13  MULTIPOLYGON (((3676327.345 5878817.393, 36764...
# 14  MULTIPOLYGON (((3578320.324 5956221.807, 35785...
# 15  MULTIPOLYGON (((3546527.162 5270229.312, 35465...
# 16  MULTIPOLYGON (((3499488.078 5289416.195, 34995...
# 17  MULTIPOLYGON (((3500500.570 5287549.006, 35005...
# 18  MULTIPOLYGON (((3623880.720 5724534.216, 36239...
# 19  MULTIPOLYGON (((3609507.014 5269598.995, 36095...
# 20  MULTIPOLYGON (((3405039.299 5989429.771, 33957...
# 21  MULTIPOLYGON (((3549699.596 5937193.593, 35498...
# 22  MULTIPOLYGON (((3500945.434 6038100.404, 35008...
# 23  MULTIPOLYGON (((3349196.246 5939969.352, 33492...
# 24  MULTIPOLYGON (((3464863.775 6102446.269, 34649...
# 25  MULTIPOLYGON (((3564167.533 6062589.511, 35640...
# 26  MULTIPOLYGON (((3797721.842 6049025.924, 37976...
# 27  MULTIPOLYGON (((3817007.470 5980584.417, 38170...
#
# [28 rows x 26 columns]

# %% [markdown]
# ## Select Region

# %% [markdown]
# ### Bundesland

# %%
lan_name = 'Mecklenburg-Vorpommern'
df_lan_region = df_lan[(df_lan['gen'] == lan_name)]
ags_lan_region = df_lan_region.loc[df_lan_region['gen'] == lan_name, ['ags']].values[0][0]
print('Region: {} - AGS: {}'.format(lan_name, ags_lan_region))
df_lan_region
# Out:
# Region: Mecklenburg-Vorpommern - AGS: 13
#    reference_date  id  ade   gf  bsg  rs ags        sdv_rs  \
# 7      2016-01-01   9  2.0  4.0  1.0  13  13  130040000000
# 26     2016-01-01  29  2.0  3.0  1.0  13  13  130040000000
# 27     2016-01-01  30  2.0  2.0  1.0  13  13  130040000000
#
#                        gen   bez  ...  sn_v1 sn_v2 sn_g fk_s3 nuts  \
# 7   Mecklenburg-Vorpommern  Land  ...     00    00  000     0  DE8
# 26  Mecklenburg-Vorpommern  Land  ...     00    00  000     0  DE8
# 27  Mecklenburg-Vorpommern  Land  ...     00    00  000     0  DE8
#
#             rs_0     ags_0         wsk          debkg_id  \
# 7   130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 26  130000000000  13000000  2014-11-01  DEBKGDL20000QBMH
# 27  130000000000  13000000  2014-11-01  DEBKGDL20000E5I7
#
#                                                  geom
# 7   MULTIPOLYGON (((3728408.028 6045375.810, 37284...
# 26  MULTIPOLYGON (((3797721.842 6049025.924, 37976...
# 27  MULTIPOLYGON (((3817007.470 5980584.417, 38170...
#
# [3 rows x 26 columns]

# %%
ax = df_lan_region.plot(figsize=(5, 5), color='white', edgecolor='black', linewidth=2)

# %% [markdown]
# ### Landkreis

# %%
df_krs_region = df_krs.loc[(df_krs['ags'].str.slice(0,2) == str(ags_lan_region))]
df_krs_region
# Out:
#     reference_date   id  ade   gf  bsg     rs    ags        sdv_rs  \
# 0       2016-01-01    1  4.0  4.0  1.0  13004  13004  130040000000
# 14      2016-01-01   14  4.0  4.0  1.0  13072  13072  130720043043
# 43      2016-01-01   70  4.0  4.0  1.0  13076  13076  130760108108
# 64      2016-01-01   73  4.0  4.0  1.0  13075  13075  130750039039
# 71      2016-01-01   83  4.0  4.0  1.0  13071  13071  130710107107
# 97      2016-01-01  315  4.0  2.0  1.0  13073  13073  130730088088
# 166     2016-01-01  134  4.0  4.0  1.0  13074  13074  130740087087
# 173     2016-01-01  365  4.0  2.0  1.0  13074  13074  130740087087
# 174     2016-01-01  366  4.0  2.0  1.0  13075  13075  130750039039
# 241     2016-01-01  189  4.0  4.0  1.0  13073  13073  130730088088
# 390     2016-01-01  359  4.0  2.0  1.0  13003  13003  130030000000
# 397     2016-01-01  368  4.0  2.0  1.0  13072  13072  130720043043
# 399     2016-01-01  370  4.0  4.0  1.0  13003  13003  130030000000
#
#                              gen               bez  ...  sn_v1 sn_v2 sn_g  \
# 0                       Schwerin  Kreisfreie Stadt  ...     00    00  000
# 14                       Rostock         Landkreis  ...     00    00  000
# 43           Ludwigslust-Parchim         Landkreis  ...     00    00  000
# 64         Vorpommern-Greifswald         Landkreis  ...     00    00  000
# 71   Mecklenburgische Seenplatte         Landkreis  ...     00    00  000
# 97              Vorpommern-Rügen         Landkreis  ...     00    00  000
# 166          Nordwestmecklenburg         Landkreis  ...     00    00  000
# 173          Nordwestmecklenburg         Landkreis  ...     00    00  000
# 174        Vorpommern-Greifswald         Landkreis  ...     00    00  000
# 241             Vorpommern-Rügen         Landkreis  ...     00    00  000
# 390                      Rostock  Kreisfreie Stadt  ...     00    00  000
# 397                      Rostock         Landkreis  ...     00    00  000
# 399                      Rostock  Kreisfreie Stadt  ...     00    00  000
#
#     fk_s3   nuts          rs_0     ags_0         wsk          debkg_id  \
# 0       R  DE804  130040000000  13004000  1990-10-03  DEBKGDL20000E26X
# 14      R  DE80K  130720000000  13072000  2011-09-04  DEBKGDL20000QGFS
# 43      R  DE80O  130760000000  13076000  2014-11-01  DEBKGDL20000QGFP
# 64      R  DE80N  130750000000  13075000  2011-09-04  DEBKGDL20000QGHU
# 71      R  DE80J  130710000000  13071000  2011-09-04  DEBKGDL20000QGHT
# 97      R  DE80L  130730000000  13073000  2011-09-04  DEBKGDL20000QGFU
# 166     R  DE80M  130740000000  13074000  2011-09-04  DEBKGDL20000QGFQ
# 173     R  DE80M  130740000000  13074000  2011-09-04  DEBKGDL20000QGFR
# 174     R  DE80N  130750000000  13075000  2011-09-04  DEBKGDL20000QGHV
# 241     R  DE80L  130730000000  13073000  2011-09-04  DEBKGDL20000QGFT
# 390     R  DE803  130030000000  13003000  2007-01-01  DEBKGDL20000003J
# 397     R  DE80K  130720000000  13072000  2011-09-04  DEBKGDL20000SRLP
# 399     R  DE803  130030000000  13003000  2007-01-01  DEBKGDL20000E375
#
#                                                   geom
# 0    MULTIPOLYGON (((3660706.955 5953427.508, 36606...
# 14   MULTIPOLYGON (((3715071.910 6018735.757, 37149...
# 43   MULTIPOLYGON (((3679382.704 5966058.229, 36794...
# 64   MULTIPOLYGON (((3782633.231 6014516.588, 37827...
# 71   MULTIPOLYGON (((3763354.096 5992152.518, 37633...
# 97   MULTIPOLYGON (((3722648.796 6032395.384, 37227...
# 166  MULTIPOLYGON (((3666146.156 5991484.670, 36662...
# 173  MULTIPOLYGON (((3648051.019 5984906.689, 36479...
# 174  MULTIPOLYGON (((3817007.470 5980584.417, 38170...
# 241  MULTIPOLYGON (((3728408.028 6045375.810, 37284...
# 390  MULTIPOLYGON (((3701671.697 6010555.626, 37021...
# 397  MULTIPOLYGON (((3670442.848 6000062.607, 36705...
# 399  MULTIPOLYGON (((3710212.206 6017219.095, 37103...
#
# [13 rows x 26 columns]

# %%
ax = df_lan_region.plot(figsize=(5, 5), color='white', edgecolor='black', linewidth=2)
df_krs_region.plot(ax=ax, alpha=0.8, color='white', edgecolor='tab:blue', linewidth=1)

# %% [markdown]
# #### Filter Landkreis

# %%
krs_name = 'Vorpommern-Rügen'
df_krs_region_filter = df_krs[(df_krs['gen'] == krs_name)]
ags_krs_region = df_krs_region_filter.loc[df_krs_region_filter['gen'] == krs_name, ['ags']].values[0][0]
print('Region: {} - AGS: {}'.format(krs_name, ags_krs_region))
# Out:
# Region: Vorpommern-Rügen - AGS: 13073

# %%
df_krs_region_filter
# Out:
#     reference_date   id  ade   gf  bsg     rs    ags        sdv_rs  \
# 97      2016-01-01  315  4.0  2.0  1.0  13073  13073  130730088088
# 241     2016-01-01  189  4.0  4.0  1.0  13073  13073  130730088088
#
#                   gen        bez  ...  sn_v1 sn_v2 sn_g fk_s3   nuts  \
# 97   Vorpommern-Rügen  Landkreis  ...     00    00  000     R  DE80L
# 241  Vorpommern-Rügen  Landkreis  ...     00    00  000     R  DE80L
#
#              rs_0     ags_0         wsk          debkg_id  \
# 97   130730000000  13073000  2011-09-04  DEBKGDL20000QGFU
# 241  130730000000  13073000  2011-09-04  DEBKGDL20000QGFT
#
#                                                   geom
# 97   MULTIPOLYGON (((3722648.796 6032395.384, 37227...
# 241  MULTIPOLYGON (((3728408.028 6045375.810, 37284...
#
# [2 rows x 26 columns]

# %%
ax = df_lan_region.plot(figsize=(5, 5), color='white', edgecolor='black', linewidth=2)
df_krs_region_filter.plot(ax=ax, alpha=0.8, color='white', edgecolor='tab:blue', linewidth=1)

# %%
ax = df_krs_region_filter.plot(figsize=(5, 5), color='white', edgecolor='tab:blue', linewidth=2)

# %% [markdown]
# ### Gemeinde

# %% [markdown]
# Use _ags_lan_region_ for entire Bundesland

# %%
df_gem_region = df_gem.loc[(df_gem['ags'].str.slice(0,2) == str(ags_lan_region))]
df_gem_region
# Out:
#       reference_date     id  ade   gf  bsg            rs       ags  \
# 35        2016-01-01   9144  6.0  2.0  1.0  130725259085  13072085
# 40        2016-01-01   9145  6.0  2.0  1.0  130735359019  13073019
# 198       2016-01-01    187  6.0  4.0  1.0  130735356023  13073023
# 243       2016-01-01    219  6.0  4.0  1.0  130755560138  13075138
# 289       2016-01-01    257  6.0  4.0  1.0  130725258109  13072109
# ...              ...    ...  ...  ...  ...           ...       ...
# 11345     2016-01-01  11338  6.0  4.0  1.0  130765664101  13076101
# 11371     2016-01-01  11370  6.0  4.0  1.0  130725256056  13072056
# 11390     2016-01-01  11390  6.0  4.0  1.0  130765657115  13076115
# 11422     2016-01-01  11422  6.0  4.0  1.0  130725255073  13072073
# 11423     2016-01-01  11423  6.0  4.0  1.0  130725255067  13072067
#
#              sdv_rs            gen       bez  ...  sn_v1 sn_v2 sn_g fk_s3  \
# 35     130725259085          Rerik     Stadt  ...     52    59  085     R
# 40     130735359019        Dranske  Gemeinde  ...     53    59  019     R
# 198    130735356023     Elmenhorst  Gemeinde  ...     53    56  023     R
# 243    130755560138        Viereck  Gemeinde  ...     55    60  138     R
# 289    130725258109        Thürkow  Gemeinde  ...     52    58  109     R
# ...             ...            ...       ...  ...    ...   ...  ...   ...
# 11345  130765664101         Mustin  Gemeinde  ...     56    64  101     R
# 11371  130725256056  Krakow am See     Stadt  ...     52    56  056     R
# 11390  130765657115       Prislich  Gemeinde  ...     56    57  115     R
# 11422  130725255073     Mühl Rosin  Gemeinde  ...     52    55  073     R
# 11423  130725255067         Lohmen  Gemeinde  ...     52    55  067     R
#
#         nuts          rs_0     ags_0         wsk          debkg_id  \
# 35     DE80K  130725259085  13072085  2011-09-04  DEBKGDL20000SRLZ
# 40     DE80L  130735359019  13073019  2011-09-04  DEBKGDL20000SRMQ
# 198    DE80L  130735356023  13073023  2011-09-04  DEBKGDL20000E3ON
# 243    DE80N  130755560138  13075138  2011-09-04  DEBKGDL20000DWO0
# 289    DE80K  130725258109  13072109  2011-09-04  DEBKGDL20000DYFQ
# ...      ...           ...       ...         ...               ...
# 11345  DE80O  130765664101  13076101  2011-09-04  DEBKGDL20000DZ77
# 11371  DE80K  130725256056  13072056  2011-09-04  DEBKGDL20000DXC2
# 11390  DE80O  130765657115  13076115  2011-09-04  DEBKGDL20000DYK4
# 11422  DE80K  130725255073  13072073  2011-09-04  DEBKGDL20000E27E
# 11423  DE80K  130725255067  13072067  2011-09-04  DEBKGDL20000DYPX
#
#                                                     geom
# 35     MULTIPOLYGON (((3670443.229 6000061.768, 36705...
# 40     MULTIPOLYGON (((3773921.152 6059879.333, 37735...
# 198    MULTIPOLYGON (((3763605.940 6020159.400, 37638...
# 243    MULTIPOLYGON (((3839591.675 5952805.347, 38397...
# 289    MULTIPOLYGON (((3734324.399 5974441.762, 37348...
# ...                                                  ...
# 11345  MULTIPOLYGON (((3696444.216 5959120.781, 36964...
# 11371  MULTIPOLYGON (((3713305.025 5959674.980, 37133...
# 11390  MULTIPOLYGON (((3676230.082 5908766.565, 36761...
# 11422  MULTIPOLYGON (((3711642.128 5964719.174, 37117...
# 11423  MULTIPOLYGON (((3704070.193 5960686.425, 37043...
#
# [789 rows x 26 columns]

# %%
ax = df_lan_region.plot(figsize=(10, 10), color='white', edgecolor='black', linewidth=2)
df_krs_region.plot(ax=ax, alpha=0.8, color='white', edgecolor='tab:blue', linewidth=1)
df_gem_region.plot(ax=ax, alpha=0.2, color='white', edgecolor='red')

# %% [markdown]
# Use _ags_krs_region_ for filtered Landkreis

# %%
df_gem_region_filter = df_gem.loc[(df_gem['ags'].str.slice(0,5) == str(ags_krs_region))]
df_gem_region_filter
# Out:
#       reference_date     id  ade   gf  bsg            rs       ags  \
# 40        2016-01-01   9145  6.0  2.0  1.0  130735359019  13073019
# 198       2016-01-01    187  6.0  4.0  1.0  130735356023  13073023
# 597       2016-01-01    540  6.0  4.0  1.0  130730011011  13073011
# 604       2016-01-01    546  6.0  4.0  1.0  130735355096  13073096
# 701       2016-01-01    639  6.0  4.0  1.0  130735360007  13073007
# ...              ...    ...  ...  ...  ...           ...       ...
# 10063     2016-01-01  10016  6.0  4.0  1.0  130735357056  13073056
# 10738     2016-01-01  10861  6.0  4.0  1.0  130735360020  13073020
# 10792     2016-01-01  10784  6.0  4.0  1.0  130735356102  13073102
# 11306     2016-01-01  11296  6.0  4.0  1.0  130735360039  13073039
# 11318     2016-01-01  11307  6.0  4.0  1.0  130735352051  13073051
#
#              sdv_rs          gen       bez  ...  sn_v1 sn_v2 sn_g fk_s3  \
# 40     130735359019      Dranske  Gemeinde  ...     53    59  019     R
# 198    130735356023   Elmenhorst  Gemeinde  ...     53    56  023     R
# 597    130730011011         Binz  Gemeinde  ...     00    11  011     R
# 604    130735355096      Velgast  Gemeinde  ...     53    55  096     R
# 701    130735360007    Bad Sülze     Stadt  ...     53    60  007     R
# ...             ...          ...       ...  ...    ...   ...  ...   ...
# 10063  130735357056  Middelhagen  Gemeinde  ...     53    57  056     R
# 10738  130735360020      Drechow  Gemeinde  ...     53    60  020     R
# 10792  130735356102  Wittenhagen  Gemeinde  ...     53    56  102     R
# 11306  130735360039  Hugoldsdorf  Gemeinde  ...     53    60  039     R
# 11318  130735352051      Löbnitz  Gemeinde  ...     53    52  051     R
#
#         nuts          rs_0     ags_0         wsk          debkg_id  \
# 40     DE80L  130735359019  13073019  2011-09-04  DEBKGDL20000SRMQ
# 198    DE80L  130735356023  13073023  2011-09-04  DEBKGDL20000E3ON
# 597    DE80L  130730011011  13073011  2011-09-04  DEBKGDL20000E07N
# 604    DE80L  130735355096  13073096  2011-09-04  DEBKGDL20000E6MP
# 701    DE80L  130735360007  13073007  2011-09-04  DEBKGDL20000E3LL
# ...      ...           ...       ...         ...               ...
# 10063  DE80L  130735357056  13073056  2011-09-04  DEBKGDL20000E4QY
# 10738  DE80L  130735360020  13073020  2011-09-04  DEBKGDL20000DXC8
# 10792  DE80L  130735356102  13073102  2011-09-04  DEBKGDL20000E6BN
# 11306  DE80L  130735360039  13073039  2011-09-04  DEBKGDL20000DXC7
# 11318  DE80L  130735352051  13073051  2011-09-04  DEBKGDL20000DZII
#
#                                                     geom
# 40     MULTIPOLYGON (((3773921.152 6059879.333, 37735...
# 198    MULTIPOLYGON (((3763605.940 6020159.400, 37638...
# 597    MULTIPOLYGON (((3796445.013 6048063.769, 37964...
# 604    MULTIPOLYGON (((3751577.882 6027504.455, 37513...
# 701    MULTIPOLYGON (((3738456.072 6006833.324, 37385...
# ...                                                  ...
# 10063  MULTIPOLYGON (((3804654.434 6034203.910, 38046...
# 10738  MULTIPOLYGON (((3748200.883 6010159.100, 37482...
# 10792  MULTIPOLYGON (((3762733.653 6016438.512, 37627...
# 11306  MULTIPOLYGON (((3746713.812 6011501.394, 37469...
# 11318  MULTIPOLYGON (((3744767.305 6027840.469, 37450...
#
# [117 rows x 26 columns]

# %%
ax = df_lan_region.plot(figsize=(10, 10), color='white', edgecolor='black', linewidth=2)
df_krs_region_filter.plot(ax=ax, alpha=0.8, color='white', edgecolor='tab:blue', linewidth=1)
df_gem_region_filter.plot(ax=ax, alpha=0.2, color='white', edgecolor='red')

# %%
ax = df_krs_region_filter.plot(figsize=(10, 10), color='white', edgecolor='tab:blue', linewidth=2)
df_gem_region_filter.plot(ax=ax, alpha=0.2, color='white', edgecolor='red')

# %% [markdown]
# ### MaStR

# %%
from saio.model_draft import bnetza_mastr_rli_v2_2_0_wind_clean as MastrWind
from saio.model_draft import bnetza_mastr_rli_v2_2_0_hydro_clean as MastrHydro
from saio.model_draft import bnetza_mastr_rli_v2_2_0_biomass_clean as MastrBiomass

# %%
Session = sessionmaker(bind=engine)
session = Session()
try:
    df_mastr_wind = saio.as_pandas(session.query(MastrWind))
    #df_mastr_hydro = saio.as_pandas(session.query(MastrHydro))
    #df_mastr_biomass = saio.as_pandas(session.query(MastrBiomass))
    session.commit()
    print('Querry successful!')
except Exception as e:
    session.rollback()
    raise
    print('Querry incomplete!')
finally:
    session.close()
# Out:
# Querry successful!

# %%
fig, ax = plt.subplots(1, figsize=(20, 20))
ax.set_aspect('equal')
ax.set_axis_off()
ax.set_title('MaStR - Powerplants')

df_mastr_wind.to_crs({'init': 'epsg:3035'}).plot(ax=ax, color='blue', edgecolor='grey', linewidth=1)

#df_mastr_hydro.to_crs({'init': 'epsg:3035'}).plot(ax=ax, color='white', alpha=.5, edgecolor='black', linewidth=2)

#df_mastr_biomass.to_crs({'init': 'epsg:3035'}).plot(ax=ax, marker='o', color='orange', markersize=5)

plt.axis('equal')
# Out:
# (3206705.5376885096, 9653036.469116995, -2061691.1759842124, 4805751.443931205)

# %% [markdown]
# ### Data Cleansing

# %%
type(df_mastr_wind)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
df_mastr_wind.Bruttoleistung = df_mastr_wind.Bruttoleistung.astype(float)
df_mastr_wind
# Out:
#           id   w-id    pu-id   lid EinheitMastrNummer      Name  \
# 0       4339   4338  1073575  1575    SME977268638521      AB41
# 1       4340   4339  1073576  1576    SME977404216101      AB42
# 2       4341   4340  1073577  1577    SME945270847446      AB47
# 3       4342   4341  1073578  1578    SME921631191304      AB48
# 4       4343   4342  1073579  1579    SME998042407225      AB52
# ...      ...    ...      ...   ...                ...       ...
# 41552  40817  40816  2388266   266    SEE954788853719     WEA 1
# 41553  40821  40820  2388373   373    SEE908658847421     WEA 2
# 41554  40936  40935  2394598   598    SEE920276062475  Dedensen
# 41555  41552  41551  2432758   758    SEE930963621908      9121
# 41556  41553  41552  2432815   815    SEE922952710656      9122
#
#                    Einheitart   Einheittyp                     Standort  \
# 0      Stromerzeugungseinheit  Windeinheit             Ostsee Cluster:
# 1      Stromerzeugungseinheit  Windeinheit             Ostsee Cluster:
# 2      Stromerzeugungseinheit  Windeinheit             Ostsee Cluster:
# 3      Stromerzeugungseinheit  Windeinheit             Ostsee Cluster:
# 4      Stromerzeugungseinheit  Windeinheit             Ostsee Cluster:
# ...                       ...          ...                          ...
# 41552  Stromerzeugungseinheit  Windeinheit             97720 NÃ¼dlingen
# 41553  Stromerzeugungseinheit  Windeinheit             97720 NÃ¼dlingen
# 41554  Stromerzeugungseinheit  Windeinheit                 30926 Seelze
# 41555  Stromerzeugungseinheit  Windeinheit  Osterhammerweg 26553 Dornum
# 41556  Stromerzeugungseinheit  Windeinheit  Osterhammerweg 26553 Dornum
#
#        Bruttoleistung  ...       Frist WasserrechtsNummer  \
# 0              6300.0  ...  2017-07-31               None
# 1              6300.0  ...  2017-07-31               None
# 2              6300.0  ...  2017-07-31               None
# 3              6300.0  ...  2017-07-31               None
# 4              6300.0  ...  2017-07-31               None
# ...               ...  ...         ...                ...
# 41552          2400.0  ...  2017-01-02               None
# 41553          2400.0  ...  2017-01-02               None
# 41554           750.0  ...        None               None
# 41555           500.0  ...        None               None
# 41556           500.0  ...        None               None
#
#       WasserrechtAblaufdatum Meldedatum_p   version_m  \
# 0                       None         None  rli_v2.2.0
# 1                       None         None  rli_v2.2.0
# 2                       None         None  rli_v2.2.0
# 3                       None         None  rli_v2.2.0
# 4                       None         None  rli_v2.2.0
# ...                      ...          ...         ...
# 41552                   None   2019-08-12  rli_v2.2.0
# 41553                   None   2019-08-12  rli_v2.2.0
# 41554                   None         None  rli_v2.2.0
# 41555                   None         None  rli_v2.2.0
# 41556                   None         None  rli_v2.2.0
#
#                       timestamp_m        lat        lon  \
# 0      2019-12-06 21:36:30.301709        NaN        NaN
# 1      2019-12-06 21:36:30.301709        NaN        NaN
# 2      2019-12-06 21:36:30.301709        NaN        NaN
# 3      2019-12-06 21:36:30.301709        NaN        NaN
# 4      2019-12-06 21:36:30.301709        NaN        NaN
# ...                           ...        ...        ...
# 41552  2019-12-06 21:36:30.301709  39.450817  15.764019
# 41553  2019-12-06 21:36:30.301709  39.446727  15.765612
# 41554  2019-12-06 21:36:30.301709  48.116464  19.099712
# 41555  2019-12-06 21:36:30.301709  53.000000   7.000000
# 41556  2019-12-06 21:36:30.301709  53.000000   7.000000
#
#                             geom  \
# 0       POINT (8.86722 54.74937)
# 1       POINT (8.86722 54.74937)
# 2       POINT (8.86722 54.74937)
# 3       POINT (8.86722 54.74937)
# 4       POINT (8.86722 54.74937)
# ...                          ...
# 41552  POINT (10.13556 50.21887)
# 41553  POINT (10.13556 50.21887)
# 41554   POINT (9.57478 52.38603)
# 41555   POINT (7.41838 53.65612)
# 41556   POINT (7.41838 53.65612)
#
#                                                  comment
# 0                               make_geom_standort_plz;
# 1                               make_geom_standort_plz;
# 2                               make_geom_standort_plz;
# 3                               make_geom_standort_plz;
# 4                               make_geom_standort_plz;
# ...                                                  ...
# 41552  make_geom; has_geom; outside_vg250_onshore; re...
# 41553  make_geom; has_geom; outside_vg250_onshore; re...
# 41554  make_geom; has_geom; outside_vg250_onshore; re...
# 41555  make_geom; has_geom; outside_vg250_onshore; re...
# 41556  make_geom; has_geom; outside_vg250_onshore; re...
#
# [41557 rows x 147 columns]

# %% [markdown]
# ## Spatial Join & Aggregation

# %% [markdown]
# https://gis.stackexchange.com/questions/102933/more-efficient-spatial-join-in-python-without-qgis-arcgis-postgis-etc/165413#165413

# %%
# CRS
print(df_mastr_wind.crs)
print(df_lan_region.crs)
print(df_krs_region.crs)
print(df_gem_region.crs)
# Out:
# {'init': 'epsg:4326'}
# {'init': 'epsg:31467'}
# {'init': 'epsg:31467'}
# {'init': 'epsg:31467'}

# %% [markdown]
# ### Bundesland

# %%
df_mastr_wind_region_lan = sjoin(df_mastr_wind.to_crs({'init': 'epsg:31467'}), df_lan_region, how='inner', op='within')
df_mastr_wind_region_lan
# Out:
#        id_left   w-id    pu-id   lid EinheitMastrNummer  \
# 5938      1206   1205     2829   829    SME928605626763
# 6151      1207   1206     2830   830    SME935947631553
# 6152      1208   1207     2831   831    SME993442279755
# 6153      1205   1204     2828   828    SME938615016980
# 6154      1201   1200     2824   824    SME943682279541
# ...        ...    ...      ...   ...                ...
# 41477    33069  33068  1973468  1468    SEE907037041924
# 41480    33370  33369  1988077    77    SEE927724896347
# 41504    37167  37166  2184557   557    SEE994131278622
# 41547    39652  39651  2328335   335    SEE906090044279
# 17247    38452  38451  2274333   333    SEE921019713975
#
#                         Name              Einheitart   Einheittyp  \
# 5938                   WEA07  Stromerzeugungseinheit  Windeinheit
# 6151                   WEA08  Stromerzeugungseinheit  Windeinheit
# 6152                   WEA09  Stromerzeugungseinheit  Windeinheit
# 6153                   WEA06  Stromerzeugungseinheit  Windeinheit
# 6154                   WEA01  Stromerzeugungseinheit  Windeinheit
# ...                      ...                     ...          ...
# 41477                1250001  Stromerzeugungseinheit  Windeinheit
# 41480         Am Stadtwald I  Stromerzeugungseinheit  Windeinheit
# 41504                 WEA 01  Stromerzeugungseinheit  Windeinheit
# 41547                 WEA 25  Stromerzeugungseinheit  Windeinheit
# 17247  WP Breitling WEA 8501  Stromerzeugungseinheit  Windeinheit
#
#                          Standort  Bruttoleistung  ... sn_k sn_v1 sn_v2 sn_g  \
# 5938   Schleusenweg 19376 Neuburg          2500.0  ...   00    00    00  000
# 6151   Schleusenweg 19376 Neuburg          2500.0  ...   00    00    00  000
# 6152   Schleusenweg 19376 Neuburg          2500.0  ...   00    00    00  000
# 6153   Schleusenweg 19376 Neuburg          2500.0  ...   00    00    00  000
# 6154   Schleusenweg 19376 Neuburg          2500.0  ...   00    00    00  000
# ...                           ...             ...  ...  ...   ...   ...  ...
# 41477              18233 Neubukow          4000.0  ...   00    00    00  000
# 41480            18516 SÃ¼derholz          4200.0  ...   00    00    00  000
# 41504             17337 Uckerland          3450.0  ...   00    00    00  000
# 41547               19370 Parchim          3450.0  ...   00    00    00  000
# 17247     Am Peez 5 18146 Rostock          2500.0  ...   00    00    00  000
#
#       fk_s3 nuts          rs_0     ags_0         wsk          debkg_id
# 5938      0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 6151      0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 6152      0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 6153      0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 6154      0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# ...     ...  ...           ...       ...         ...               ...
# 41477     0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 41480     0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 41504     0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 41547     0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000004A
# 17247     0  DE8  130000000000  13000000  2014-11-01  DEBKGDL20000E5I7
#
# [2581 rows x 173 columns]

# %%
ax = df_lan_region.plot(figsize=(10, 10), color='white', edgecolor='black')
df_mastr_wind_region_lan.plot(ax=ax, alpha=0.5, color='blue', edgecolor='black')

# %%
df_agg = df_mastr_wind_region_lan.groupby('ags_0')['Bruttoleistung'].sum()
df_lan_region_sum = df_lan_region.join(df_agg, on='ags_0')
df_lan_region_sum
# Out:
#    reference_date  id  ade   gf  bsg  rs ags        sdv_rs  \
# 7      2016-01-01   9  2.0  4.0  1.0  13  13  130040000000
# 26     2016-01-01  29  2.0  3.0  1.0  13  13  130040000000
# 27     2016-01-01  30  2.0  2.0  1.0  13  13  130040000000
#
#                        gen   bez  ...  sn_v2 sn_g fk_s3 nuts          rs_0  \
# 7   Mecklenburg-Vorpommern  Land  ...     00  000     0  DE8  130000000000
# 26  Mecklenburg-Vorpommern  Land  ...     00  000     0  DE8  130000000000
# 27  Mecklenburg-Vorpommern  Land  ...     00  000     0  DE8  130000000000
#
#        ags_0         wsk          debkg_id  \
# 7   13000000  2014-11-01  DEBKGDL20000004A
# 26  13000000  2014-11-01  DEBKGDL20000QBMH
# 27  13000000  2014-11-01  DEBKGDL20000E5I7
#
#                                                  geom Bruttoleistung
# 7   MULTIPOLYGON (((3728408.028 6045375.810, 37284...     4817531.45
# 26  MULTIPOLYGON (((3797721.842 6049025.924, 37976...     4817531.45
# 27  MULTIPOLYGON (((3817007.470 5980584.417, 38170...     4817531.45
#
# [3 rows x 27 columns]

# %%
ax = df_lan_region.plot(figsize=(10, 10), color='white', edgecolor='black')
df_lan_region_sum.plot(column='Bruttoleistung', cmap='Greens', label='Capacity in MW', ax=ax)

# %% [markdown]
# ### Landkreis

# %%
df_mastr_wind_region_krs = sjoin(df_mastr_wind.to_crs({'init': 'epsg:31467'}), df_krs_region, how='inner', op='within')
df_mastr_wind_region_krs.head(3)
# Out:
#       id_left  w-id pu-id  lid EinheitMastrNummer   Name  \
# 5938     1206  1205  2829  829    SME928605626763  WEA07
# 6151     1207  1206  2830  830    SME935947631553  WEA08
# 6152     1208  1207  2831  831    SME993442279755  WEA09
#
#                   Einheitart   Einheittyp                    Standort  \
# 5938  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
# 6151  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
# 6152  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
#
#       Bruttoleistung  ... sn_k sn_v1 sn_v2 sn_g fk_s3   nuts          rs_0  \
# 5938          2500.0  ...   76    00    00  000     R  DE80O  130760000000
# 6151          2500.0  ...   76    00    00  000     R  DE80O  130760000000
# 6152          2500.0  ...   76    00    00  000     R  DE80O  130760000000
#
#          ags_0         wsk          debkg_id
# 5938  13076000  2014-11-01  DEBKGDL20000QGFP
# 6151  13076000  2014-11-01  DEBKGDL20000QGFP
# 6152  13076000  2014-11-01  DEBKGDL20000QGFP
#
# [3 rows x 173 columns]

# %%
ax = df_lan_region.plot(figsize=(10, 10), color='white', edgecolor='black')
df_krs_region.plot(ax=ax, alpha=0.5, color='white', edgecolor='grey')
df_mastr_wind_region_krs.plot(ax=ax, alpha=0.5, color='blue', edgecolor='black')

# %%
df_mastr_wind_region_krs.Bruttoleistung = df_mastr_wind_region_krs.Bruttoleistung.astype(float) #type(df_mastr_wind_gem)
df_agg = df_mastr_wind_region_krs.groupby('ags_0')['Bruttoleistung'].sum()
df_krs_region_sum = df_krs_region.join(df_agg, on='ags_0')
df_krs_region_sum
# Out:
#     reference_date   id  ade   gf  bsg     rs    ags        sdv_rs  \
# 0       2016-01-01    1  4.0  4.0  1.0  13004  13004  130040000000
# 14      2016-01-01   14  4.0  4.0  1.0  13072  13072  130720043043
# 43      2016-01-01   70  4.0  4.0  1.0  13076  13076  130760108108
# 64      2016-01-01   73  4.0  4.0  1.0  13075  13075  130750039039
# 71      2016-01-01   83  4.0  4.0  1.0  13071  13071  130710107107
# 97      2016-01-01  315  4.0  2.0  1.0  13073  13073  130730088088
# 166     2016-01-01  134  4.0  4.0  1.0  13074  13074  130740087087
# 173     2016-01-01  365  4.0  2.0  1.0  13074  13074  130740087087
# 174     2016-01-01  366  4.0  2.0  1.0  13075  13075  130750039039
# 241     2016-01-01  189  4.0  4.0  1.0  13073  13073  130730088088
# 390     2016-01-01  359  4.0  2.0  1.0  13003  13003  130030000000
# 397     2016-01-01  368  4.0  2.0  1.0  13072  13072  130720043043
# 399     2016-01-01  370  4.0  4.0  1.0  13003  13003  130030000000
#
#                              gen               bez  ...  sn_v2 sn_g fk_s3  \
# 0                       Schwerin  Kreisfreie Stadt  ...     00  000     R
# 14                       Rostock         Landkreis  ...     00  000     R
# 43           Ludwigslust-Parchim         Landkreis  ...     00  000     R
# 64         Vorpommern-Greifswald         Landkreis  ...     00  000     R
# 71   Mecklenburgische Seenplatte         Landkreis  ...     00  000     R
# 97              Vorpommern-Rügen         Landkreis  ...     00  000     R
# 166          Nordwestmecklenburg         Landkreis  ...     00  000     R
# 173          Nordwestmecklenburg         Landkreis  ...     00  000     R
# 174        Vorpommern-Greifswald         Landkreis  ...     00  000     R
# 241             Vorpommern-Rügen         Landkreis  ...     00  000     R
# 390                      Rostock  Kreisfreie Stadt  ...     00  000     R
# 397                      Rostock         Landkreis  ...     00  000     R
# 399                      Rostock  Kreisfreie Stadt  ...     00  000     R
#
#       nuts          rs_0     ags_0         wsk          debkg_id  \
# 0    DE804  130040000000  13004000  1990-10-03  DEBKGDL20000E26X
# 14   DE80K  130720000000  13072000  2011-09-04  DEBKGDL20000QGFS
# 43   DE80O  130760000000  13076000  2014-11-01  DEBKGDL20000QGFP
# 64   DE80N  130750000000  13075000  2011-09-04  DEBKGDL20000QGHU
# 71   DE80J  130710000000  13071000  2011-09-04  DEBKGDL20000QGHT
# 97   DE80L  130730000000  13073000  2011-09-04  DEBKGDL20000QGFU
# 166  DE80M  130740000000  13074000  2011-09-04  DEBKGDL20000QGFQ
# 173  DE80M  130740000000  13074000  2011-09-04  DEBKGDL20000QGFR
# 174  DE80N  130750000000  13075000  2011-09-04  DEBKGDL20000QGHV
# 241  DE80L  130730000000  13073000  2011-09-04  DEBKGDL20000QGFT
# 390  DE803  130030000000  13003000  2007-01-01  DEBKGDL20000003J
# 397  DE80K  130720000000  13072000  2011-09-04  DEBKGDL20000SRLP
# 399  DE803  130030000000  13003000  2007-01-01  DEBKGDL20000E375
#
#                                                   geom Bruttoleistung
# 0    MULTIPOLYGON (((3660706.955 5953427.508, 36606...       30000.00
# 14   MULTIPOLYGON (((3715071.910 6018735.757, 37149...     1045390.90
# 43   MULTIPOLYGON (((3679382.704 5966058.229, 36794...      855775.00
# 64   MULTIPOLYGON (((3782633.231 6014516.588, 37827...      881243.90
# 71   MULTIPOLYGON (((3763354.096 5992152.518, 37633...     1030312.95
# 97   MULTIPOLYGON (((3722648.796 6032395.384, 37227...      640038.20
# 166  MULTIPOLYGON (((3666146.156 5991484.670, 36662...      309368.00
# 173  MULTIPOLYGON (((3648051.019 5984906.689, 36479...      309368.00
# 174  MULTIPOLYGON (((3817007.470 5980584.417, 38170...      881243.90
# 241  MULTIPOLYGON (((3728408.028 6045375.810, 37284...      640038.20
# 390  MULTIPOLYGON (((3701671.697 6010555.626, 37021...       25402.50
# 397  MULTIPOLYGON (((3670442.848 6000062.607, 36705...     1045390.90
# 399  MULTIPOLYGON (((3710212.206 6017219.095, 37103...       25402.50
#
# [13 rows x 27 columns]

# %%
ax = df_krs_region.plot(figsize=(10, 10), color='white', edgecolor='black')
df_krs_region_sum.plot(column='Bruttoleistung', cmap='Greens', label='Capacity in MW', ax=ax)

# %% [markdown]
# ### Gemeinde

# %%
df_mastr_wind_region_gem = sjoin(df_mastr_wind.to_crs({'init': 'epsg:31467'}), df_gem_region, how='inner', op='within')
df_mastr_wind_region_gem.head()
# Out:
#       id_left  w-id pu-id  lid EinheitMastrNummer   Name  \
# 5938     1206  1205  2829  829    SME928605626763  WEA07
# 6151     1207  1206  2830  830    SME935947631553  WEA08
# 6152     1208  1207  2831  831    SME993442279755  WEA09
# 6153     1205  1204  2828  828    SME938615016980  WEA06
# 6154     1201  1200  2824  824    SME943682279541  WEA01
#
#                   Einheitart   Einheittyp                    Standort  \
# 5938  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
# 6151  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
# 6152  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
# 6153  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
# 6154  Stromerzeugungseinheit  Windeinheit  Schleusenweg 19376 Neuburg
#
#       Bruttoleistung  ... sn_k sn_v1 sn_v2 sn_g fk_s3   nuts          rs_0  \
# 5938          2500.0  ...   76    56    55  132     R  DE80O  130765655132
# 6151          2500.0  ...   76    56    55  132     R  DE80O  130765655132
# 6152          2500.0  ...   76    56    55  132     R  DE80O  130765655132
# 6153          2500.0  ...   76    56    55  132     R  DE80O  130765655132
# 6154          2500.0  ...   76    56    55  132     R  DE80O  130765655132
#
#          ags_0         wsk          debkg_id
# 5938  13076132  2011-09-04  DEBKGDL20000E34Z
# 6151  13076132  2011-09-04  DEBKGDL20000E34Z
# 6152  13076132  2011-09-04  DEBKGDL20000E34Z
# 6153  13076132  2011-09-04  DEBKGDL20000E34Z
# 6154  13076132  2011-09-04  DEBKGDL20000E34Z
#
# [5 rows x 173 columns]

# %%
ax = df_lan_region.plot(figsize=(10, 10), color='white', edgecolor='black')
df_gem_region.plot(ax=ax, alpha=0.5, color='white', edgecolor='grey')
df_mastr_wind_region_gem.plot(ax=ax, alpha=0.5, color='blue', edgecolor='black')

# %%
df_mastr_wind_region_gem.Bruttoleistung = df_mastr_wind_region_gem.Bruttoleistung.astype(float) #type(df_mastr_wind_gem)
df_agg = df_mastr_wind_region_gem.groupby('ags_0')['Bruttoleistung'].sum()
df_gem_region_sum = df_gem_region.join(df_agg, on='ags_0')
df_gem_region_sum.head()
# Out:
#     reference_date    id  ade   gf  bsg            rs       ags        sdv_rs  \
# 35      2016-01-01  9144  6.0  2.0  1.0  130725259085  13072085  130725259085
# 40      2016-01-01  9145  6.0  2.0  1.0  130735359019  13073019  130735359019
# 198     2016-01-01   187  6.0  4.0  1.0  130735356023  13073023  130735356023
# 243     2016-01-01   219  6.0  4.0  1.0  130755560138  13075138  130755560138
# 289     2016-01-01   257  6.0  4.0  1.0  130725258109  13072109  130725258109
#
#             gen       bez  ...  sn_v2 sn_g fk_s3   nuts          rs_0  \
# 35        Rerik     Stadt  ...     59  085     R  DE80K  130725259085
# 40      Dranske  Gemeinde  ...     59  019     R  DE80L  130735359019
# 198  Elmenhorst  Gemeinde  ...     56  023     R  DE80L  130735356023
# 243     Viereck  Gemeinde  ...     60  138     R  DE80N  130755560138
# 289     Thürkow  Gemeinde  ...     58  109     R  DE80K  130725258109
#
#         ags_0         wsk          debkg_id  \
# 35   13072085  2011-09-04  DEBKGDL20000SRLZ
# 40   13073019  2011-09-04  DEBKGDL20000SRMQ
# 198  13073023  2011-09-04  DEBKGDL20000E3ON
# 243  13075138  2011-09-04  DEBKGDL20000DWO0
# 289  13072109  2011-09-04  DEBKGDL20000DYFQ
#
#                                                   geom Bruttoleistung
# 35   MULTIPOLYGON (((3670443.229 6000061.768, 36705...         8850.0
# 40   MULTIPOLYGON (((3773921.152 6059879.333, 37735...            NaN
# 198  MULTIPOLYGON (((3763605.940 6020159.400, 37638...            NaN
# 243  MULTIPOLYGON (((3839591.675 5952805.347, 38397...            NaN
# 289  MULTIPOLYGON (((3734324.399 5974441.762, 37348...            NaN
#
# [5 rows x 27 columns]

# %%
ax = df_gem_region.plot(figsize=(10, 10), color='white', edgecolor='black')
df_gem_region_sum.plot(column='Bruttoleistung', cmap='Greens', label='Capacity in MW', ax=ax)
# Out:
# D:\Anaconda3\envs\d_py37_mastr\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
