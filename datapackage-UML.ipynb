# %% [markdown]
# <img src="http://reiner-lemoine-institut.de//wp-content/uploads/2015/09/rlilogo.png" alt="RLI" height="100" width="100" align="right"/>
#
# # UML - datapackage
#
# This script uses the package _iplantuml_ for plotting UML. <br>
# See tutorial for installation and other instructions.

# %%
__copyright__ = "Reiner Lemoine Institut"
__license__   = "GNU Affero General Public License Version 3 (AGPL-3.0)"
__url__       = "https://github.com/OpenEnergyPlatform/examples/blob/master/LICENSE"
__author__    = "oakca"

# %%
import iplantuml

# %% [markdown]
# # Contents
#
# The following UML diagrams will be displayed in the following:
# 1. mastr_wind
# 2. mastr_hydro
# 3. mastr_biomass
# 4. mastr_solar

# %% [markdown]
# ## UML - datapackage - mastr_wind

# %%
# %%plantuml --jar
#
# @startuml
# 'ERM definitions:
#
# skinparam tabSize 2
# sprite $key [17x12/16z] bOqv3e1030CJRzPn9Fx_NWY7n4eqJ3TJs6OVa5pTpD-5tl3YyFHG-4DsqAOnWgawWp0r0KGagDuGMYMJxbMrBxzLPJ_O0G00
# !define Table(name,desc) class name as "desc" << (T,#FFAAAA) >>
# !define primary_key(x) <$key><b>x</b>
# !define foreign_key(x) <$key>x
# !define unique <b>U</b>
# !define not_null <b>N</b>
# hide methods
# hide stereotypes
#
# Table(wind, "mastr_wind") {
#     primary_key(id) \t INTEGER
#     --
#     EinheitMastrNummer \t VARCHAR
#     lid \t INTEGER
#     Name \t VARCHAR
#     Einheitart \t VARCHAR
#     Einheittyp \t VARCHAR
#     Standort \t VARCHAR
#     Bruttoleistung \t VARCHAR
#     Erzeugungsleistung \t VARCHAR
#     EinheitBetriebsstatus \t VARCHAR
#     Anlagenbetreiber \t VARCHAR
#     EegMastrNummer \t VARCHAR
#     KwkMastrNummer \t VARCHAR
#     SpeMastrNummer \t VARCHAR
#     GenMastrNummer \t VARCHAR
#     BestandsanlageMastrNummer \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten \t VARCHAR
#     version \t VARCHAR
#     timestamp \t VARCHAR
#     lid_w \t INTEGER
#     Ergebniscode \t VARCHAR
#     AufrufVeraltet \t BOOLEAN
#     AufrufLebenszeitEnde \t VARCHAR
#     AufrufVersion \t VARCHAR
#     DatumLetzteAktualisierung \t VARCHAR
#     LokationMastrNummer \t VARCHAR
#     NetzbetreiberpruefungStatus \t VARCHAR
#     NetzbetreiberpruefungDatum \t VARCHAR
#     AnlagenbetreiberMastrNummer \t VARCHAR
#     Land \t VARCHAR
#     Bundesland \t VARCHAR
#     Landkreis \t VARCHAR
#     Gemeinde \t VARCHAR
#     Gemeindeschluessel \t VARCHAR
#     Postleitzahl \t VARCHAR
#     Gemarkung \t VARCHAR
#     FlurFlurstuecknummern \t VARCHAR
#     Strasse \t VARCHAR
#     StrasseNichtGefunden \t BOOLEAN
#     Hausnummer \t VARCHAR
#     HausnummerNichtGefunden \t BOOLEAN
#     Adresszusatz \t VARCHAR
#     Ort \t VARCHAR
#     Laengengrad \t VARCHAR
#     Breitengrad \t VARCHAR
#     UtmZonenwert \t VARCHAR
#     UtmEast \t VARCHAR
#     UtmNorth \t VARCHAR
#     GaussKruegerHoch \t VARCHAR
#     GaussKruegerRechts \t VARCHAR
#     Meldedatum \t VARCHAR
#     GeplantesInbetriebnahmedatum \t VARCHAR
#     Inbetriebnahmedatum \t VARCHAR
#     DatumEndgueltigeStilllegung \t VARCHAR
#     DatumBeginnVoruebergehendeStilllegung \t VARCHAR
#     DatumWiederaufnahmeBetrieb \t VARCHAR
#     EinheitBetriebsstatus_w \t VARCHAR
#     BestandsanlageMastrNummer_w \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten_w \t VARCHAR
#     NameStromerzeugungseinheit \t VARCHAR
#     Weic \t VARCHAR
#     WeicDisplayName \t VARCHAR
#     Kraftwerksnummer \t VARCHAR
#     Energietraeger \t VARCHAR
#     Bruttoleistung_w \t NUMERIC
#     Nettonennleistung \t NUMERIC
#     AnschlussAnHoechstOderHochSpannung \t BOOLEAN
#     Schwarzstartfaehigkeit \t VARCHAR
#     Inselbetriebsfaehigkeit \t VARCHAR
#     Einsatzverantwortlicher \t VARCHAR
#     FernsteuerbarkeitNb \t VARCHAR
#     FernsteuerbarkeitDv \t VARCHAR
#     FernsteuerbarkeitDr \t VARCHAR
#     Einspeisungsart \t VARCHAR
#     PraequalifiziertFuerRegelenergie \t VARCHAR
#     GenMastrNummer_w \t VARCHAR
#     NameWindpark \t VARCHAR
#     Lage \t VARCHAR
#     Seelage \t VARCHAR
#     ClusterOstsee \t VARCHAR
#     ClusterNordsee \t VARCHAR
#     Technologie \t VARCHAR
#     Typenbezeichnung \t VARCHAR
#     Nabenhoehe \t VARCHAR
#     Rotordurchmesser \t VARCHAR
#     AuflageAbschaltungLeistungsbegrenzung \t VARCHAR
#     Wassertiefe \t VARCHAR
#     Kuestenentfernung \t VARCHAR
#     EegMastrNummer_w \t VARCHAR
#     HerstellerID \t VARCHAR
#     HerstellerName \t VARCHAR
#     version_w \t VARCHAR
#     timestamp_w \t VARCHAR
#     lid_e \t INTEGER
#     Ergebniscode_e \t VARCHAR
#     AufrufVeraltet_e \t BOOLEAN
#     AufrufLebenszeitEnde_e \t VARCHAR
#     AufrufVersion_e \t VARCHAR
#     Meldedatum_e \t VARCHAR
#     DatumLetzteAktualisierung_e \t VARCHAR
#     EegInbetriebnahmedatum \t VARCHAR
#     AnlagenkennzifferAnlagenregister \t VARCHAR
#     AnlagenschluesselEeg \t VARCHAR
#     PrototypAnlage \t VARCHAR
#     PilotAnlage \t VARCHAR
#     InstallierteLeistung \t VARCHAR
#     VerhaeltnisErtragsschaetzungReferenzertrag \t VARCHAR
#     VerhaeltnisReferenzertragErtrag5Jahre \t VARCHAR
#     VerhaeltnisReferenzertragErtrag10Jahre \t VARCHAR
#     VerhaeltnisReferenzertragErtrag15Jahre \t VARCHAR
#     AusschreibungZuschlag \t None
#     Zuschlagsnummer \t None
#     AnlageBetriebsstatus \t None
#     VerknuepfteEinheit \t None
#     version_e \t None
#     timestamp_e \t None
# }
#
# @enduml

# %% [markdown]
# ## UML - datapackage - mastr_hydro

# %%
# %%plantuml --jar
#
# @startuml
# 'ERM definitions:
#
# skinparam tabSize 2
# sprite $key [17x12/16z] bOqv3e1030CJRzPn9Fx_NWY7n4eqJ3TJs6OVa5pTpD-5tl3YyFHG-4DsqAOnWgawWp0r0KGagDuGMYMJxbMrBxzLPJ_O0G00
# !define Table(name,desc) class name as "desc" << (T,#FFAAAA) >>
# !define primary_key(x) <$key><b>x</b>
# !define foreign_key(x) <$key>x
# !define unique <b>U</b>
# !define not_null <b>N</b>
# hide methods
# hide stereotypes
#
# Table(wind, "mastr_hydro") {
#     primary_key(id) \t INTEGER
#     --
#     EinheitMastrNummer \t VARCHAR
#     lid \t INTEGER
#     Name \t VARCHAR
#     Einheitart \t VARCHAR
#     Einheittyp \t VARCHAR
#     Standort \t VARCHAR
#     Bruttoleistung \t VARCHAR
#     Erzeugungsleistung \t VARCHAR
#     EinheitBetriebsstatus \t VARCHAR
#     Anlagenbetreiber \t VARCHAR
#     EegMastrNummer \t VARCHAR
#     KwkMastrNummer \t VARCHAR
#     SpeMastrNummer \t VARCHAR
#     GenMastrNummer \t VARCHAR
#     BestandsanlageMastrNummer \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten \t VARCHAR
#     version \t VARCHAR
#     timestamp \t VARCHAR
#     lid_w \t INTEGER
#     Ergebniscode \t VARCHAR
#     AufrufVeraltet \t BOOLEAN
#     AufrufLebenszeitEnde \t VARCHAR
#     AufrufVersion \t VARCHAR
#     DatumLetzteAktualisierung \t VARCHAR
#     LokationMastrNummer \t VARCHAR
#     NetzbetreiberpruefungStatus \t VARCHAR
#     NetzbetreiberpruefungDatum \t VARCHAR
#     AnlagenbetreiberMastrNummer \t VARCHAR
#     Land \t VARCHAR
#     Bundesland \t VARCHAR
#     Landkreis \t VARCHAR
#     Gemeinde \t VARCHAR
#     Gemeindeschluessel \t VARCHAR
#     Postleitzahl \t VARCHAR
#     Gemarkung \t VARCHAR
#     FlurFlurstuecknummern \t VARCHAR
#     Strasse \t VARCHAR
#     StrasseNichtGefunden \t BOOLEAN
#     Hausnummer \t VARCHAR
#     HausnummerNichtGefunden \t BOOLEAN
#     Adresszusatz \t VARCHAR
#     Ort \t VARCHAR
#     Laengengrad \t VARCHAR
#     Breitengrad \t VARCHAR
#     UtmZonenwert \t VARCHAR
#     UtmEast \t VARCHAR
#     UtmNorth \t VARCHAR
#     GaussKruegerHoch \t VARCHAR
#     GaussKruegerRechts \t VARCHAR
#     Meldedatum \t VARCHAR
#     GeplantesInbetriebnahmedatum \t VARCHAR
#     Inbetriebnahmedatum \t VARCHAR
#     DatumEndgueltigeStilllegung \t VARCHAR
#     DatumBeginnVoruebergehendeStilllegung \t VARCHAR
#     DatumWiederaufnahmeBetrieb \t VARCHAR
#     EinheitBetriebsstatus_w \t VARCHAR
#     BestandsanlageMastrNummer_w \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten_w \t VARCHAR
#     NameStromerzeugungseinheit \t VARCHAR
#     Weic \t VARCHAR
#     WeicDisplayName \t VARCHAR
#     Kraftwerksnummer \t VARCHAR
#     Energietraeger \t VARCHAR
#     Bruttoleistung_w \t NUMERIC
#     Nettonennleistung \t NUMERIC
#     AnschlussAnHoechstOderHochSpannung \t BOOLEAN
#     Schwarzstartfaehigkeit \t VARCHAR
#     Inselbetriebsfaehigkeit \t VARCHAR
#     Einsatzverantwortlicher \t VARCHAR
#     FernsteuerbarkeitNb \t VARCHAR
#     FernsteuerbarkeitDv \t VARCHAR
#     FernsteuerbarkeitDr \t VARCHAR
#     Einspeisungsart \t VARCHAR
#     PraequalifiziertFuerRegelenergie \t VARCHAR
#     GenMastrNummer_w \t VARCHAR
#     NameKraftwerk \t VARCHAR
#     ArtDerWasserkraftanlage \t VARCHAR
#     AnzeigeEinerStilllegung \t VARCHAR
#     ArtDerStilllegung \t VARCHAR
#     DatumBeginnVorlaeufigenOderEndgueltigenStilllegung \t VARCHAR
#     MinderungStromerzeugung \t VARCHAR
#     BestandteilGrenzkraftwerk \t VARCHAR
#     NettonennleistungDeutschland \t VARCHAR
#     ArtDesZuflusses \t VARCHAR
#     EegMastrNummer_w \t VARCHAR
#     version_w \t VARCHAR
#     timestamp_w \t VARCHAR
#     lid_e \t INTEGER
#     Ergebniscode_e \t VARCHAR
#     AufrufVeraltet_e \t BOOLEAN
#     AufrufLebenszeitEnde_e \t VARCHAR
#     AufrufVersion_e \t VARCHAR
#     Meldedatum_e \t VARCHAR
#     DatumLetzteAktualisierung_e \t VARCHAR
#     EegInbetriebnahmedatum \t VARCHAR
#     AnlagenschluesselEeg \t VARCHAR
#     AnlagenkennzifferAnlagenregister \t VARCHAR
#     InstallierteLeistung \t VARCHAR
#     AnlageBetriebsstatus \t None
#     Ertuechtigung \t VARCHAR \t None
#     VerknuepfteEinheit \t None
#     version_e \t None
#     timestamp_e \t None
# }
#
# @enduml

# %% [markdown]
# ## UML - datapackage - mastr_biomass

# %%
# %%plantuml --jar
#
# @startuml
# 'ERM definitions:
#
# skinparam tabSize 2
# sprite $key [17x12/16z] bOqv3e1030CJRzPn9Fx_NWY7n4eqJ3TJs6OVa5pTpD-5tl3YyFHG-4DsqAOnWgawWp0r0KGagDuGMYMJxbMrBxzLPJ_O0G00
# !define Table(name,desc) class name as "desc" << (T,#FFAAAA) >>
# !define primary_key(x) <$key><b>x</b>
# !define foreign_key(x) <$key>x
# !define unique <b>U</b>
# !define not_null <b>N</b>
# hide methods
# hide stereotypes
#
# Table(wind, "mastr_biomass") {
#     primary_key(id) \t INTEGER
#     --
#     EinheitMastrNummer \t VARCHAR
#     lid \t INTEGER
#     Name \t VARCHAR
#     Einheitart \t VARCHAR
#     Einheittyp \t VARCHAR
#     Standort \t VARCHAR
#     Bruttoleistung \t VARCHAR
#     Erzeugungsleistung \t VARCHAR
#     EinheitBetriebsstatus \t VARCHAR
#     Anlagenbetreiber \t VARCHAR
#     EegMastrNummer \t VARCHAR
#     KwkMastrNummer \t VARCHAR
#     SpeMastrNummer \t VARCHAR
#     GenMastrNummer \t VARCHAR
#     BestandsanlageMastrNummer \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten \t VARCHAR
#     version \t VARCHAR
#     timestamp \t VARCHAR
#     lid_w \t INTEGER
#     Ergebniscode \t VARCHAR
#     AufrufVeraltet \t BOOLEAN
#     AufrufLebenszeitEnde \t VARCHAR
#     AufrufVersion \t VARCHAR
#     DatumLetzteAktualisierung \t VARCHAR
#     LokationMastrNummer \t VARCHAR
#     NetzbetreiberpruefungStatus \t VARCHAR
#     NetzbetreiberpruefungDatum \t VARCHAR
#     AnlagenbetreiberMastrNummer \t VARCHAR
#     Land \t VARCHAR
#     Bundesland \t VARCHAR
#     Landkreis \t VARCHAR
#     Gemeinde \t VARCHAR
#     Gemeindeschluessel \t VARCHAR
#     Postleitzahl \t VARCHAR
#     Gemarkung \t VARCHAR
#     FlurFlurstuecknummern \t VARCHAR
#     Strasse \t VARCHAR
#     StrasseNichtGefunden \t BOOLEAN
#     Hausnummer \t VARCHAR
#     HausnummerNichtGefunden \t BOOLEAN
#     Adresszusatz \t VARCHAR
#     Ort \t VARCHAR
#     Laengengrad \t VARCHAR
#     Breitengrad \t VARCHAR
#     UtmZonenwert \t VARCHAR
#     UtmEast \t VARCHAR
#     UtmNorth \t VARCHAR
#     GaussKruegerHoch \t VARCHAR
#     GaussKruegerRechts \t VARCHAR
#     Meldedatum \t VARCHAR
#     GeplantesInbetriebnahmedatum \t VARCHAR
#     Inbetriebnahmedatum \t VARCHAR
#     DatumEndgueltigeStilllegung \t VARCHAR
#     DatumBeginnVoruebergehendeStilllegung \t VARCHAR
#     DatumWiederaufnahmeBetrieb \t VARCHAR
#     EinheitBetriebsstatus_w \t VARCHAR
#     BestandsanlageMastrNummer_w \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten_w \t VARCHAR
#     NameStromerzeugungseinheit \t VARCHAR
#     Weic \t VARCHAR
#     WeicDisplayName \t VARCHAR
#     Kraftwerksnummer \t VARCHAR
#     Energietraeger \t VARCHAR
#     Bruttoleistung_w \t NUMERIC
#     Nettonennleistung \t NUMERIC
#     AnschlussAnHoechstOderHochSpannung \t BOOLEAN
#     Schwarzstartfaehigkeit \t VARCHAR
#     Inselbetriebsfaehigkeit \t VARCHAR
#     Einsatzverantwortlicher \t VARCHAR
#     FernsteuerbarkeitNb \t VARCHAR
#     FernsteuerbarkeitDv \t VARCHAR
#     FernsteuerbarkeitDr \t VARCHAR
#     Einspeisungsart \t VARCHAR
#     PraequalifiziertFuerRegelenergie \t VARCHAR
#     GenMastrNummer_w \t VARCHAR
#     Hauptbrennstoff \t VARCHAR
#     Biomasseart \t VARCHAR
#     Technologie \t VARCHAR
#     EegMastrNummer_w \t VARCHAR
#     KwkMastrNummer_w \t VARCHAR
#     version_w \t VARCHAR
#     timestamp_w \t VARCHAR
#     lid_e \t INTEGER
#     Ergebniscode_e \t VARCHAR
#     AufrufVeraltet_e \t BOOLEAN
#     AufrufLebenszeitEnde_e \t VARCHAR
#     AufrufVersion_e \t VARCHAR
#     Meldedatum_e \t VARCHAR
#     DatumLetzteAktualisierung_e \t VARCHAR
#     EegInbetriebnahmedatum \t VARCHAR
#     AnlagenschluesselEeg \t VARCHAR
#     AnlagenkennzifferAnlagenregister \t VARCHAR
#     InstallierteLeistung \t VARCHAR
#     AusschliesslicheVerwendungBiomasse \t VARCHAR
#     AusschreibungZuschlag \t VARCHAR
#     Zuschlagsnummer \t None
#     BiogasInanspruchnahmeFlexiPraemie \t VARCHAR
#     BiogasDatumInanspruchnahmeFlexiPraemie \t VARCHAR
#     BiogasLeistungserhoehung \t VARCHAR
#     BiogasDatumLeistungserhoehung \t VARCHAR
#     BiogasUmfangLeistungserhoehung \t VARCHAR
#     BiogasGaserzeugungskapazitaet \t VARCHAR
#     BiogasHoechstbemessungsleistung \t VARCHAR
#     BiomethanErstmaligerEinsatz \t VARCHAR
#     AnlageBetriebsstatus \t None
#     VerknuepfteEinheit \t None
#     version_e \t None
#     timestamp_e \t None
# }
#
# @enduml

# %% [markdown]
# ## UML - datapackage - mastr_solar

# %%
# %%plantuml --jar
#
# @startuml
# 'ERM definitions:
#
# skinparam tabSize 2
# sprite $key [17x12/16z] bOqv3e1030CJRzPn9Fx_NWY7n4eqJ3TJs6OVa5pTpD-5tl3YyFHG-4DsqAOnWgawWp0r0KGagDuGMYMJxbMrBxzLPJ_O0G00
# !define Table(name,desc) class name as "desc" << (T,#FFAAAA) >>
# !define primary_key(x) <$key><b>x</b>
# !define foreign_key(x) <$key>x
# !define unique <b>U</b>
# !define not_null <b>N</b>
# hide methods
# hide stereotypes
#
# Table(wind, "mastr_solar") {
#     primary_key(id) \t INTEGER
#     --
#     EinheitMastrNummer \t VARCHAR
#     lid \t INTEGER
#     Name \t VARCHAR
#     Einheitart \t VARCHAR
#     Einheittyp \t VARCHAR
#     Standort \t VARCHAR
#     Bruttoleistung \t VARCHAR
#     Erzeugungsleistung \t VARCHAR
#     EinheitBetriebsstatus \t VARCHAR
#     Anlagenbetreiber \t VARCHAR
#     EegMastrNummer \t VARCHAR
#     KwkMastrNummer \t VARCHAR
#     SpeMastrNummer \t VARCHAR
#     GenMastrNummer \t VARCHAR
#     BestandsanlageMastrNummer \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten \t VARCHAR
#     version \t VARCHAR
#     timestamp \t VARCHAR
#     lid_w \t INTEGER
#     Ergebniscode \t VARCHAR
#     AufrufVeraltet \t BOOLEAN
#     AufrufLebenszeitEnde \t VARCHAR
#     AufrufVersion \t VARCHAR
#     DatumLetzteAktualisierung \t VARCHAR
#     LokationMastrNummer \t VARCHAR
#     NetzbetreiberpruefungStatus \t VARCHAR
#     NetzbetreiberpruefungDatum \t VARCHAR
#     AnlagenbetreiberMastrNummer \t VARCHAR
#     Land \t VARCHAR
#     Bundesland \t VARCHAR
#     Landkreis \t VARCHAR
#     Gemeinde \t VARCHAR
#     Gemeindeschluessel \t VARCHAR
#     Postleitzahl \t VARCHAR
#     Gemarkung \t VARCHAR
#     FlurFlurstuecknummern \t VARCHAR
#     Strasse \t VARCHAR
#     StrasseNichtGefunden \t BOOLEAN
#     Hausnummer \t VARCHAR
#     HausnummerNichtGefunden \t BOOLEAN
#     Adresszusatz \t VARCHAR
#     Ort \t VARCHAR
#     Laengengrad \t VARCHAR
#     Breitengrad \t VARCHAR
#     UtmZonenwert \t VARCHAR
#     UtmEast \t VARCHAR
#     UtmNorth \t VARCHAR
#     GaussKruegerHoch \t VARCHAR
#     GaussKruegerRechts \t VARCHAR
#     Meldedatum \t VARCHAR
#     GeplantesInbetriebnahmedatum \t VARCHAR
#     Inbetriebnahmedatum \t VARCHAR
#     DatumEndgueltigeStilllegung \t VARCHAR
#     DatumBeginnVoruebergehendeStilllegung \t VARCHAR
#     DatumWiederaufnahmeBetrieb \t VARCHAR
#     EinheitBetriebsstatus_w \t VARCHAR
#     BestandsanlageMastrNummer_w \t VARCHAR
#     NichtVorhandenInMigriertenEinheiten_w \t VARCHAR
#     NameStromerzeugungseinheit \t VARCHAR
#     Weic \t VARCHAR
#     WeicDisplayName \t VARCHAR
#     Kraftwerksnummer \t VARCHAR
#     Energietraeger \t VARCHAR
#     Bruttoleistung_w \t NUMERIC
#     Nettonennleistung \t NUMERIC
#     AnschlussAnHoechstOderHochSpannung \t BOOLEAN
#     Schwarzstartfaehigkeit \t VARCHAR
#     Inselbetriebsfaehigkeit \t VARCHAR
#     Einsatzverantwortlicher \t VARCHAR
#     FernsteuerbarkeitNb \t VARCHAR
#     FernsteuerbarkeitDv \t VARCHAR
#     FernsteuerbarkeitDr \t VARCHAR
#     Einspeisungsart \t VARCHAR
#     PraequalifiziertFuerRegelenergie \t VARCHAR
#     GenMastrNummer_w \t VARCHAR
#     zugeordneteWirkleistungWechselrichter \t VARCHAR
#     GemeinsamerWechselrichterMitSpeicher \t VARCHAR
#     AnzahlModule \t VARCHAR
#     Lage \t VARCHAR
#     Leistungsbegrenzung \t VARCHAR
#     EinheitlicheAusrichtungUndNeigungswinkel \t VARCHAR
#     Hauptausrichtung \t VARCHAR
#     HauptausrichtungNeigungswinkel \t VARCHAR
#     Nebenausrichtung \t VARCHAR
#     NebenausrichtungNeigungswinkel \t VARCHAR
#     InAnspruchGenommeneFlaeche \t VARCHAR
#     ArtDerFlaeche \t VARCHAR
#     InAnspruchGenommeneAckerflaeche \t VARCHAR
#     Nutzungsbereich \t VARCHAR
#     EegMastrNummer_w \t VARCHAR
#     version_w \t VARCHAR
#     timestamp_w \t VARCHAR
#     lid_e \t INTEGER
#     Ergebniscode_e \t VARCHAR
#     AufrufVeraltet_e \t BOOLEAN
#     AufrufLebenszeitEnde_e \t VARCHAR
#     AufrufVersion_e \t VARCHAR
#     Meldedatum_e \t VARCHAR
#     DatumLetzteAktualisierung_e \t VARCHAR
#     EegInbetriebnahmedatum \t VARCHAR
#     AnlagenschluesselEeg \t VARCHAR
#     AnlagenkennzifferAnlagenregister \t VARCHAR
#     InstallierteLeistung \t VARCHAR
#     RegistrierungsnummerPvMeldeportal \t VARCHAR
#     MieterstromZugeordnet \t VARCHAR
#     MieterstromMeldedatum \t VARCHAR
#     MieterstromErsteZuordnungZuschlag \t VARCHAR
#     AusschreibungZuschlag \t None
#     ZugeordneteGebotsmenge \t None
#     Zuschlagsnummer \t None
#     AnlageBetriebsstatus \t None
#     VerknuepfteEinheit \t None
#     version_e \t None
#     timestamp_e \t None
# }
#
# @enduml
